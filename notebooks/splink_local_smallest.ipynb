# %% [markdown]
# # Following splink's example, for the synthetic dataset
#
# We follow the steps done in
#
# `https://moj-analytical-services.github.io/splink/demos/examples/duckdb/transactions.html`
#
# while adapting the datasets for the synthetic dataset.

# %%
# Required dependencies
import pandas as pd
import numpy as np
import os
import sys
import yaml

from splink import DuckDBAPI, Linker, SettingsCreator, block_on


import matplotlib.pyplot as plt
import pyarrow as pa
import pyarrow.parquet as pq

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
plt.style.use('seaborn-v0_8')
# %matplotlib inline

# Notebook config helper, handles path config and package imports 
from notebook_helper import setup_notebook_environment
helper = setup_notebook_environment()

from em_pipeline.data_loader import (
    load_pair_dfs_from_paths,
    standardise_dt,
    plot_numerical_distribution
)
from em_pipeline.splink_helper import (
    build_api_with_con,
    get_blocking_rules,
    get_estimating_blocking_rules,
    get_numerical_comparison,
    get_datetime_comparison,
    get_category_comparison
)

# %%
NOTEBOOK_NAME = "splink_local_smallest"

MEM_LIMIT  = "24GB"
TEMP_DIR   = "/tmp"

# Column names used in the synthetic dataset
LEFT_ID_COL   = "local_source_id"      # appears in both df1 & df2 after loading
RIGHT_ID_COL  = "local_source_id"
UNIQUE_ID_COL = "row_id"                # we eventually attempt to build this for labelling.
GROUND_TRUTH_ID_COL = "latent_event_id"      # used for ground truths
CATEGORICAL_COL   = "categorical"
NUMERIC_COL       = "numerical_noisy"
DATETIME_COL      = "datetime_noisy"

# How strict we want the initial random‑match estimate to be
RECALL_FOR_PRIOR = 0.99   # same as the original notebook

# %%
dataset_a_path, dataset_b_path = helper.ensure_dataset_exists('smallest')

print(f"Dataset A path: {dataset_a_path}")
print(f"Dataset B path: {dataset_b_path}")
# Out:
# Dataset A path: /home/local/KLASS/steven.zhu/Documents/entity_resolution_demo/notebooks/../data/smallest_dataset_a.parquet
# Dataset B path: /home/local/KLASS/steven.zhu/Documents/entity_resolution_demo/notebooks/../data/smallest_dataset_b.parquet

# %%
df1, df2 = load_pair_dfs_from_paths(dataset_a_path, dataset_b_path)

print(f"\nDataset A shape: {df1.shape}")
print(f"Dataset B shape: {df2.shape}")

print(f"\nDataset A columns: {list(df1.columns)}")
print(f"Dataset B columns: {list(df2.columns)}")
# Out:
# Dataset A shape: (1669, 6)
# Dataset B shape: (2086, 6)
#
# Dataset A columns: ['global_entity_id', 'local_source_id', 'categorical', 'numerical_noisy', 'datetime_noisy', 'latent_event_id']
# Dataset B columns: ['global_entity_id', 'local_source_id', 'categorical', 'numerical_noisy', 'datetime_noisy', 'latent_event_id']

# %%
df1["row_id"] = "df1_" + df1.index.astype(str)
df2["row_id"] = "df2_" + df2.index.astype(str)
df1
# Out:
#       global_entity_id local_source_id categorical  numerical_noisy  \
# 0               100051      DF1_100051       CAT_2          1549.11
# 1               100068      DF1_100068       CAT_4           725.30
# 2               100075      DF1_100075       CAT_4           356.41
# 3               100068      DF1_100068       CAT_3          1710.56
# 4               100007      DF1_100007       CAT_6           716.24
# ...                ...             ...         ...              ...
# 1664            100024      DF1_100024       CAT_5           518.77
# 1665            100005      DF1_100005       CAT_7          1715.73
# 1666            100020      DF1_100020       CAT_4           549.15
# 1667            100052      DF1_100052       CAT_4           557.59
# 1668            100092      DF1_100092       CAT_2           398.10
#
#                     datetime_noisy latent_event_id    row_id
# 0    2025-12-31 20:47:22.032547758          OVER_0     df1_0
# 1    2025-12-31 23:59:38.962020717       UNI_A_147     df1_1
# 2    2026-01-01 02:40:20.372498903          OVER_2     df1_2
# 3    2026-01-01 05:05:58.177891854       UNI_A_148     df1_3
# 4    2026-01-01 06:52:24.998262806       UNI_A_149     df1_4
# ...                            ...             ...       ...
# 1664 2026-05-31 11:16:58.073592622      UNI_A_1664  df1_1664
# 1665 2026-05-31 16:55:07.536510765      UNI_A_1665  df1_1665
# 1666 2026-05-31 18:37:17.209879152      UNI_A_1666  df1_1666
# 1667 2026-05-31 19:31:23.912624442      UNI_A_1667  df1_1667
# 1668 2026-06-01 00:33:10.571869959      UNI_A_1668  df1_1668
#
# [1669 rows x 7 columns]

# %% [markdown]
# ### Basic EDA, processing

# %%
plot_numerical_distribution(df1, df2, "numerical_noisy")

# %%
# Basic preprocessing - we currently assume we do not have consistency in time across both DFs. 
# If this is no longer the case, just remove this line and update the datetime comparisons/blocking accordingly.
standardise_dt(df1, df2, DATETIME_COL)
# Out:
# Set datetime_noisy to date for both df1 and df2.

# %% [markdown]
# ### We can take a look at the distributions of the data with profile_columns

# %%
from splink.exploratory import profile_columns

db_api = build_api_with_con(MEM_LIMIT, TEMP_DIR)

profile_columns(
    [df1, df2],
    db_api=db_api,
    column_expressions=[
        "categorical",
        "datetime_noisy",
        "numerical_noisy",
    ],
)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Splink's blocking analysis tool
#
# We can use this to take a look at how effective our blocking is. Each increment introduces more unique pairs (w.r.t. previous blocking rules) into the total - the approach here is to get rid of pairs that we KNOW cannot be matches.

# %%
from splink.blocking_analysis import (
    cumulative_comparisons_to_be_scored_from_blocking_rules_chart
)

brs = get_blocking_rules()

cumulative_comparisons_to_be_scored_from_blocking_rules_chart(
    table_or_tables=[df1, df2],
    blocking_rules=brs,
    db_api=db_api,
    link_type="link_only",
    unique_id_column_name=UNIQUE_ID_COL
)
# Out:
# alt.Chart(...)

# %% [markdown]
# We've dropped the number of comparisons from somewhere north of 12 million pairs to roughly 8 million - a 30%+ reduction. Given we have better heuristics about pairs that are definitely not matches, we can further reduce this.

# %% [markdown]
# ### Pulling comparisons, setting up splink for estimation

# %%
# We use the preset comparison levels for the artificial dataset, these can be found and tweaked at em_pipeline/comparisons.py
numerical_noisy_comparison = get_numerical_comparison(num_col=NUMERIC_COL)
datetime_noisy_comparison = get_datetime_comparison(dt_col=DATETIME_COL)
categorical_comparison = get_category_comparison(cat_col=CATEGORICAL_COL)

settings = SettingsCreator(
    link_type="link_only", 
    unique_id_column_name=UNIQUE_ID_COL,
    blocking_rules_to_generate_predictions=brs,
    max_iterations=50,
    comparisons=[
        numerical_noisy_comparison,
        categorical_comparison,
        datetime_noisy_comparison
    ],
    retain_intermediate_calculation_columns=True,
    additional_columns_to_retain=["local_source_id", "latent_event_id"],
)

linker = Linker(
    [df1, df2],
    settings,
    db_api=db_api
)

# %%
# "training" the linker - we first estimate an overall prior pi - basically the likelihood of a match.
# we do this by estimating it with a set of strict blockers that we know MUST be matches.

linker.training.estimate_probability_two_random_records_match(
    get_estimating_blocking_rules(), recall=0.9
)
# Out:
# Probability two random records match is estimated to be  6.1e-05.
# This means that amongst all possible pairwise record comparisons, one in 16,405.13 are expected to match.  With 3,481,534 total possible comparisons, we expect a total of around 212.22 matching pairs

# %%
# Making estimates for u values.

linker.training.estimate_u_using_random_sampling(max_pairs=1e8)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - numerical_noisy (no m values are trained).
#     - categorical (no m values are trained).
#     - datetime_noisy (no m values are trained).

# %%
# We now estimate m values, we do this with a two-pass fixing one column and estimating for all columns BUT that one.
# In this case, we care about just a basic, loose set of blockers so that our EM has enough pairs to make estimations
# for various bins.

# Pass 1 - estimate parameters blocking on date.
linker.training.estimate_parameters_using_expectation_maximisation(
     """
        ABS(
            epoch(CAST(l.datetime_noisy AS TIMESTAMP)) - 
            epoch(CAST(r.datetime_noisy AS TIMESTAMP))
        ) <= 172800
    """
)

# Pass 2 - estimate parameters blocking on categorical
linker.training.estimate_parameters_using_expectation_maximisation(
    """
    (ABS(l.numerical_noisy - r.numerical_noisy) / NULLIF(l.numerical_noisy, 0)) <= 0.15
    """
)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
#
#         ABS(
#             epoch(CAST(l.datetime_noisy AS TIMESTAMP)) -
#             epoch(CAST(r.datetime_noisy AS TIMESTAMP))
#         ) <= 172800
#
#
# Parameter estimates will be made for the following comparison(s):
#     - numerical_noisy
#     - categorical
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - datetime_noisy
#
# Iteration 1: Largest change in params was -0.00869 in the m_probability of categorical, level `All other comparisons`
# Iteration 2: Largest change in params was 0.00719 in the m_probability of categorical, level `Exact match on categorical`
# Iteration 3: Largest change in params was 0.00592 in the m_probability of categorical, level `Exact match on categorical`
# Iteration 4: Largest change in params was -0.00485 in the m_probability of categorical, level `All other comparisons`
# Iteration 5: Largest change in params was 0.00396 in the m_probability of categorical, level `Exact match on categorical`
# Iteration 6: Largest change in params was 0.00323 in the m_probability of categorical, level `Exact match on categorical`
# Iteration 7: Largest change in params was 0.00265 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 8: Largest change in params was 0.00219 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 9: Largest change in params was 0.00182 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 10: Largest change in params was 0.0015 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 11: Largest change in params was 0.00124 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 12: Largest change in params was 0.00102 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 13: Largest change in params was 0.00084 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 14: Largest change in params was 0.00069 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 15: Largest change in params was 0.000566 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 16: Largest change in params was 0.000463 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 17: Largest change in params was 0.000377 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 18: Largest change in params was 0.000305 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 19: Largest change in params was 0.000246 in the m_probability of numerical_noisy, level `Percentage difference of 'numerical_noisy' within 5.00%`
# Iteration 20: Largest change in params was 0.0002 in the m_probability of categorical, level `Exact match on categorical`
# Iteration 21: Largest change in params was -0.000168 in the m_probability of categorical, level `All other comparisons`
# Iteration 22: Largest change in params was 0.000142 in the m_probability of categorical, level `Exact match on categorical`
# Iteration 23: Largest change in params was 0.000121 in the m_probability of categorical, level `Exact match on categorical`
# Iteration 24: Largest change in params was -0.000103 in the m_probability of categorical, level `All other comparisons`
# Iteration 25: Largest change in params was 8.92e-05 in the m_probability of categorical, level `Exact match on categorical`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - datetime_noisy (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
#
#     (ABS(l.numerical_noisy - r.numerical_noisy) / NULLIF(l.numerical_noisy, 0)) <= 0.15
#
#
# Parameter estimates will be made for the following comparison(s):
#     - categorical
#     - datetime_noisy
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - numerical_noisy
#
# Iteration 1: Largest change in params was 0.00869 in the m_probability of datetime_noisy, level `Same day`
# Iteration 2: Largest change in params was 0.00668 in the m_probability of datetime_noisy, level `Same day`
# Iteration 3: Largest change in params was 0.00511 in the m_probability of datetime_noisy, level `Same day`
# Iteration 4: Largest change in params was 0.00389 in the m_probability of datetime_noisy, level `Same day`
# Iteration 5: Largest change in params was 0.00295 in the m_probability of datetime_noisy, level `Same day`
# Iteration 6: Largest change in params was 0.00223 in the m_probability of datetime_noisy, level `Same day`
# Iteration 7: Largest change in params was 0.00168 in the m_probability of datetime_noisy, level `Same day`
# Iteration 8: Largest change in params was 0.00126 in the m_probability of datetime_noisy, level `Same day`
# Iteration 9: Largest change in params was 0.000935 in the m_probability of datetime_noisy, level `Same day`
# Iteration 10: Largest change in params was 0.000688 in the m_probability of datetime_noisy, level `Same day`
# Iteration 11: Largest change in params was 0.000498 in the m_probability of datetime_noisy, level `Same day`
# Iteration 12: Largest change in params was 0.000353 in the m_probability of datetime_noisy, level `Same day`
# Iteration 13: Largest change in params was 0.00024 in the m_probability of datetime_noisy, level `Same day`
# Iteration 14: Largest change in params was 0.000154 in the m_probability of datetime_noisy, level `Same day`
# Iteration 15: Largest change in params was -9.55e-05 in the m_probability of datetime_noisy, level `<=5 days`
#
# EM converged after 15 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# <EMTrainingSession, blocking on
#     (ABS(l.numerical_noisy - r.numerical_noisy) / NULLIF(l.numerical_noisy, 0)) <= 0.15
#     , deactivating comparisons numerical_noisy>

# %%
# We can view the estimated match weights

linker.visualisations.match_weights_chart()
# Out:
# /home/local/KLASS/steven.zhu/miniconda3/envs/GlobalEM/lib/python3.11/site-packages/altair/vegalite/v6/api.py:4138: UserWarning: Automatically deduplicated selection parameter with identical configuration. If you want independent parameters, explicitly name them differently (e.g., name='param1', name='param2'). See https://github.com/vega/altair/issues/3891
#   return _tp.from_dict(dct, validate=validate)
# alt.VConcatChart(...)

# %%
df_predict = linker.inference.predict()
pd_predict = df_predict.as_pandas_dataframe()
# Out:
# Blocking time: 0.86 seconds
# Predict time: 0.53 seconds

# %%
pd_predict
# Out:
#          match_weight  match_probability         source_dataset_l  \
# 0          -18.411311       2.868415e-06  __splink__input_table_0
# 1          -27.724104       4.510381e-09  __splink__input_table_0
# 2          -27.724104       4.510381e-09  __splink__input_table_0
# 3          -24.842769       3.323391e-08  __splink__input_table_0
# 4          -18.411311       2.868415e-06  __splink__input_table_0
# ...               ...                ...                      ...
# 1394501    -31.268547       3.865713e-10  __splink__input_table_0
# 1394502    -31.268547       3.865713e-10  __splink__input_table_0
# 1394503    -31.268547       3.865713e-10  __splink__input_table_0
# 1394504    -31.268547       3.865713e-10  __splink__input_table_0
# 1394505    -31.268547       3.865713e-10  __splink__input_table_0
#
#                 source_dataset_r  row_id_l  row_id_r  numerical_noisy_l  \
# 0        __splink__input_table_1   df1_195  df2_1062                NaN
# 1        __splink__input_table_1   df1_300  df2_1063            1048.72
# 2        __splink__input_table_1   df1_128  df2_1064             550.26
# 3        __splink__input_table_1   df1_300  df2_1066            1048.72
# 4        __splink__input_table_1   df1_321  df2_1067             339.50
# ...                          ...       ...       ...                ...
# 1394501  __splink__input_table_1  df1_1078  df2_1566                NaN
# 1394502  __splink__input_table_1  df1_1078  df2_1568                NaN
# 1394503  __splink__input_table_1  df1_1078  df2_1570                NaN
# 1394504  __splink__input_table_1  df1_1078  df2_1571                NaN
# 1394505  __splink__input_table_1  df1_1078  df2_1572                NaN
#
#          numerical_noisy_r  gamma_numerical_noisy  bf_numerical_noisy  \
# 0                   803.89                     -1            1.000000
# 1                   337.04                      0            0.001572
# 2                  1122.23                      0            0.001572
# 3                  1232.39                      2            0.011586
# 4                      NaN                     -1            1.000000
# ...                    ...                    ...                 ...
# 1394501             205.09                     -1            1.000000
# 1394502             155.67                     -1            1.000000
# 1394503             933.36                     -1            1.000000
# 1394504             332.13                     -1            1.000000
# 1394505             782.23                     -1            1.000000
#
#         categorical_l categorical_r  gamma_categorical  bf_categorical  \
# 0               CAT_6         CAT_6                  1        9.965853
# 1               CAT_3         CAT_3                  1        9.965853
# 2               CAT_0         CAT_0                  1        9.965853
# 3               CAT_3         CAT_3                  1        9.965853
# 4               CAT_2         CAT_2                  1        9.965853
# ...               ...           ...                ...             ...
# 1394501         CAT_8         CAT_9                  0        0.001343
# 1394502         CAT_8         CAT_6                  0        0.001343
# 1394503         CAT_8         CAT_7                  0        0.001343
# 1394504         CAT_8         CAT_0                  0        0.001343
# 1394505         CAT_8         CAT_1                  0        0.001343
#
#         datetime_noisy_l datetime_noisy_r  gamma_datetime_noisy  \
# 0             2026-01-19       2026-03-21                     0
# 1             2026-01-29       2026-03-21                     0
# 2             2026-01-13       2026-03-21                     0
# 3             2026-01-29       2026-03-21                     0
# 4             2026-01-31       2026-03-21                     0
# ...                  ...              ...                   ...
# 1394501       2026-04-10       2026-04-28                     0
# 1394502       2026-04-10       2026-04-28                     0
# 1394503       2026-04-10       2026-04-28                     0
# 1394504       2026-04-10       2026-04-28                     0
# 1394505       2026-04-10       2026-04-28                     0
#
#          bf_datetime_noisy local_source_id_l local_source_id_r  \
# 0                 0.004722        DF1_100025        DF2_100016
# 1                 0.004722        DF1_100004        DF2_100070
# 2                 0.004722        DF1_100094        DF2_100064
# 3                 0.004722        DF1_100004        DF2_100082
# 4                 0.004722        DF1_100086        DF2_100044
# ...                    ...               ...               ...
# 1394501           0.004722        DF1_100079        DF2_100055
# 1394502           0.004722        DF1_100079        DF2_100008
# 1394503           0.004722        DF1_100079        DF2_100013
# 1394504           0.004722        DF1_100079        DF2_100019
# 1394505           0.004722        DF1_100079        DF2_100009
#
#         latent_event_id_l latent_event_id_r match_key
# 0               UNI_A_320       UNIQ_B_2653         0
# 1               UNI_A_415       UNIQ_B_2654         0
# 2               UNI_A_259       UNIQ_B_2655         0
# 3               UNI_A_415       UNIQ_B_2657         0
# 4               UNI_A_434       UNIQ_B_2658         0
# ...                   ...               ...       ...
# 1394501        UNI_A_1128       UNIQ_B_3121         2
# 1394502        UNI_A_1128       UNIQ_B_3123         2
# 1394503        UNI_A_1128       UNIQ_B_3125         2
# 1394504        UNI_A_1128       UNIQ_B_3126         2
# 1394505        UNI_A_1128       UNIQ_B_3127         2
#
# [1394506 rows x 23 columns]

# %%
# 2. Flag true matches inside the scored pool
pd_predict["is_true_match"] = (
    pd_predict["latent_event_id_l"] == pd_predict["latent_event_id_r"]
).astype(int)

# 3. Get the total true match ceiling via a fast 1-to-1 merge count
# This catches matches that were blocked, ensuring Recall remains accurate
total_true_matches = (
    df1[["latent_event_id"]]
    .merge(df2[["latent_event_id"]], on="latent_event_id")
    .shape[0]
)

# 4. Generate metrics across thresholds (0.0 to 1.0)
thresholds = np.linspace(0.0, 1.0, 101)
curve_data = []

for t in thresholds:
    # Filter predictions at current probability threshold
    pred_positive = pd_predict["match_probability"] >= t

    tp = ((pred_positive) & (pd_predict["is_true_match"] == 1)).sum()
    fp = ((pred_positive) & (pd_predict["is_true_match"] == 0)).sum()

    # Calculate metrics with standard division-by-zero safeguards
    precision = tp / (tp + fp) if (tp + fp) > 0 else 1.0
    recall = tp / total_true_matches if total_true_matches > 0 else 0.0
    f1 = (
        2 * (precision * recall) / (precision + recall)
        if (precision + recall) > 0
        else 0.0
    )

    curve_data.append(
        {"threshold": t, "precision": precision, "recall": recall, "f1_score": f1}
    )

df_curve = pd.DataFrame(curve_data)

print("--- CORE PERFORMANCE THRESHOLDS ---")
print(df_curve.head(20))
# Out:
# --- CORE PERFORMANCE THRESHOLDS ---
#     threshold  precision    recall  f1_score
# 0        0.00   0.000105  1.000000  0.000211
# 1        0.01   0.217213  0.721088  0.333858
# 2        0.02   0.217213  0.721088  0.333858
# 3        0.03   0.217213  0.721088  0.333858
# 4        0.04   0.217213  0.721088  0.333858
# 5        0.05   0.217213  0.721088  0.333858
# 6        0.06   0.217213  0.721088  0.333858
# 7        0.07   0.217213  0.721088  0.333858
# 8        0.08   0.217213  0.721088  0.333858
# 9        0.09   0.444444  0.625850  0.519774
# 10       0.10   0.444444  0.625850  0.519774
# 11       0.11   0.444444  0.625850  0.519774
# 12       0.12   0.444444  0.625850  0.519774
# 13       0.13   0.444444  0.625850  0.519774
# 14       0.14   0.444444  0.625850  0.519774
# 15       0.15   0.444444  0.625850  0.519774
# 16       0.16   0.444444  0.625850  0.519774
# 17       0.17   0.444444  0.625850  0.519774
# 18       0.18   0.444444  0.625850  0.519774
# 19       0.19   0.444444  0.625850  0.519774

# %%
from notebook_helper import save_chart

plt.figure(figsize=(10, 6))
plt.plot(df_curve["threshold"], df_curve["precision"], label="Precision", color="blue", lw=2)
plt.plot(df_curve["threshold"], df_curve["recall"], label="Recall", color="orange", lw=2)
plt.plot(df_curve["threshold"], df_curve["f1_score"], label="F1-Score", color="green", linestyle="--")

plt.title("Custom Model Evaluation Curve (By Match Probability)")
plt.xlabel("Match Probability Threshold")
plt.ylabel("Score")
plt.legend(loc="lower left")
plt.grid(True, alpha=0.3)

# Save it using our helper:
save_chart(plt.gcf(), NOTEBOOK_NAME, "threshold_curve")
plt.show()
plt.close()

# %% [markdown]
# ### Reviewing our results

# %%
linker.evaluation.accuracy_analysis_from_labels_column(
    GROUND_TRUTH_ID_COL, 
    output_type="threshold_selection",
    add_metrics=["f1", "accuracy"]
)
# Out:
# Blocking time: 0.85 seconds
# Predict time: 0.65 seconds
# alt.HConcatChart(...)

# %%
linker.evaluation.unlinkables_chart()
# Out:
# alt.LayerChart(...)

# %%
from notebook_helper import get_savable_visualisations

viz = get_savable_visualisations(NOTEBOOK_NAME, linker)
viz.match_weights_chart().save_image("match_weights_chart")
viz.unlinkables_chart().save_image("unlinkables_chart")
# Out:
# /home/local/KLASS/steven.zhu/miniconda3/envs/GlobalEM/lib/python3.11/site-packages/altair/vegalite/v6/api.py:4138: UserWarning: Automatically deduplicated selection parameter with identical configuration. If you want independent parameters, explicitly name them differently (e.g., name='param1', name='param2'). See https://github.com/vega/altair/issues/3891
#   return _tp.from_dict(dct, validate=validate)
# '/home/local/KLASS/steven.zhu/Documents/entity_resolution_demo/notebooks/images/splink_local_smallest/unlinkables_chart.png'

# %% [markdown]
# ## We notice that when we have less discriminatory fields, our results are less spectacular - let's evaluate what might be happening.

# %%
linker.visualisations.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# A lot of the comparisons are generally dragged massively down
# This could be due to the blocking/comparison methods we are using - but since we don't actually care
# about the actual value, but more of the overall ranking, we just review our false positives and false negs.

# %%
# Select the columns you want to visually inspect
inspect_cols = [
    "match_probability", 
    "latent_event_id_l", "latent_event_id_r", 
    "categorical_l", "categorical_r", 
    "numerical_noisy_l", "numerical_noisy_r",
    "datetime_noisy_l", "datetime_noisy_r"
]

# False positives
fp_examples = pd_predict[pd_predict["is_true_match"] == 0].sort_values(
    by="match_probability", ascending=False
)

fp_examples.head(20)
# Out:
#          match_weight  match_probability         source_dataset_l  \
# 1059368      1.404067           0.725762  __splink__input_table_0
# 1074888      1.404067           0.725762  __splink__input_table_0
# 1090465      1.404067           0.725762  __splink__input_table_0
# 1566         1.404067           0.725762  __splink__input_table_0
# 1100181      1.404067           0.725762  __splink__input_table_0
# 819158       1.404067           0.725762  __splink__input_table_0
# 895057       1.404067           0.725762  __splink__input_table_0
# 840377       1.404067           0.725762  __splink__input_table_0
# 1024210      1.404067           0.725762  __splink__input_table_0
# 1121454      1.404067           0.725762  __splink__input_table_0
# 1092342      1.404067           0.725762  __splink__input_table_0
# 883009       1.404067           0.725762  __splink__input_table_0
# 1135186      1.404067           0.725762  __splink__input_table_0
# 14688        1.404067           0.725762  __splink__input_table_0
# 11099        1.404067           0.725762  __splink__input_table_0
# 1086403      1.404067           0.725762  __splink__input_table_0
# 809392       1.404067           0.725762  __splink__input_table_0
# 1072830      1.404067           0.725762  __splink__input_table_0
# 1121439      1.404067           0.725762  __splink__input_table_0
# 853852       1.404067           0.725762  __splink__input_table_0
#
#                 source_dataset_r  row_id_l  row_id_r  numerical_noisy_l  \
# 1059368  __splink__input_table_1  df1_1542  df2_1936             525.63
# 1074888  __splink__input_table_1  df1_1438  df2_1787             790.06
# 1090465  __splink__input_table_1  df1_1359  df2_1696             254.70
# 1566     __splink__input_table_1   df1_520   df2_650             221.29
# 1100181  __splink__input_table_1  df1_1322  df2_1620            1424.62
# 819158   __splink__input_table_1   df1_877  df2_1108             354.93
# 895057   __splink__input_table_1   df1_499   df2_622             432.52
# 840377   __splink__input_table_1   df1_626   df2_772             166.87
# 1024210  __splink__input_table_1  df1_1649  df2_2025             413.80
# 1121454  __splink__input_table_1  df1_1089  df2_1347            1794.54
# 1092342  __splink__input_table_1  df1_1317  df2_1613            1951.18
# 883009   __splink__input_table_1   df1_226   df2_308            1772.40
# 1135186  __splink__input_table_1  df1_1117  df2_1375            2104.83
# 14688    __splink__input_table_1    df1_23    df2_34             456.14
# 11099    __splink__input_table_1   df1_288   df2_383             187.59
# 1086403  __splink__input_table_1  df1_1283  df2_1548             193.52
# 809392   __splink__input_table_1   df1_903  df2_1132             184.80
# 1072830  __splink__input_table_1  df1_1361  df2_1683             309.38
# 1121439  __splink__input_table_1  df1_1087  df2_1331            1165.38
# 853852   __splink__input_table_1   df1_431   df2_532             531.23
#
#          numerical_noisy_r  gamma_numerical_noisy  bf_numerical_noisy  \
# 1059368             538.91                      4           29.543322
# 1074888             797.60                      4           29.543322
# 1090465             247.42                      4           29.543322
# 1566                225.16                      4           29.543322
# 1100181            1497.26                      4           29.543322
# 819158              368.12                      4           29.543322
# 895057              422.93                      4           29.543322
# 840377              173.75                      4           29.543322
# 1024210             398.95                      4           29.543322
# 1121454            1844.95                      4           29.543322
# 1092342            1863.59                      4           29.543322
# 883009             1840.80                      4           29.543322
# 1135186            2064.36                      4           29.543322
# 14688               444.71                      4           29.543322
# 11099               178.29                      4           29.543322
# 1086403             197.84                      4           29.543322
# 809392              175.94                      4           29.543322
# 1072830             307.33                      4           29.543322
# 1121439            1155.49                      4           29.543322
# 853852              520.90                      4           29.543322
#
#         categorical_l categorical_r  gamma_categorical  bf_categorical  \
# 1059368         CAT_4         CAT_4                  1        9.965853
# 1074888         CAT_7         CAT_7                  1        9.965853
# 1090465         CAT_7         CAT_7                  1        9.965853
# 1566            CAT_4         CAT_4                  1        9.965853
# 1100181         CAT_9         CAT_9                  1        9.965853
# 819158          CAT_7         CAT_7                  1        9.965853
# 895057          CAT_1         CAT_1                  1        9.965853
# 840377          CAT_8         CAT_8                  1        9.965853
# 1024210         CAT_1         CAT_1                  1        9.965853
# 1121454         CAT_0         CAT_0                  1        9.965853
# 1092342         CAT_3         CAT_3                  1        9.965853
# 883009          CAT_0         CAT_0                  1        9.965853
# 1135186         CAT_9         CAT_9                  1        9.965853
# 14688           CAT_8         CAT_8                  1        9.965853
# 11099           CAT_7         CAT_7                  1        9.965853
# 1086403         CAT_0         CAT_0                  1        9.965853
# 809392          CAT_1         CAT_1                  1        9.965853
# 1072830         CAT_6         CAT_6                  1        9.965853
# 1121439         CAT_6         CAT_6                  1        9.965853
# 853852          CAT_5         CAT_5                  1        9.965853
#
#         datetime_noisy_l datetime_noisy_r  gamma_datetime_noisy  \
# 1059368       2026-05-22       2026-05-22                     3
# 1074888       2026-05-11       2026-05-11                     3
# 1090465       2026-05-05       2026-05-05                     3
# 1566          2026-02-19       2026-02-19                     3
# 1100181       2026-04-30       2026-04-30                     3
# 819158        2026-03-24       2026-03-24                     3
# 895057        2026-02-18       2026-02-18                     3
# 840377        2026-03-01       2026-03-01                     3
# 1024210       2026-05-29       2026-05-29                     3
# 1121454       2026-04-11       2026-04-11                     3
# 1092342       2026-04-30       2026-04-30                     3
# 883009        2026-01-22       2026-01-22                     3
# 1135186       2026-04-13       2026-04-13                     3
# 14688         2026-01-03       2026-01-03                     3
# 11099         2026-01-27       2026-01-27                     3
# 1086403       2026-04-27       2026-04-27                     3
# 809392        2026-03-26       2026-03-26                     3
# 1072830       2026-05-05       2026-05-05                     3
# 1121439       2026-04-10       2026-04-10                     3
# 853852        2026-02-09       2026-02-09                     3
#
#          bf_datetime_noisy local_source_id_l local_source_id_r  \
# 1059368          147.45039        DF1_100024        DF2_100008
# 1074888          147.45039        DF1_100010        DF2_100062
# 1090465          147.45039        DF1_100017        DF2_100019
# 1566             147.45039        DF1_100029        DF1_100051
# 1100181          147.45039        DF1_100021        DF2_100048
# 819158           147.45039        DF1_100089        DF2_100035
# 895057           147.45039        DF1_100074        DF2_100077
# 840377           147.45039        DF1_100037        DF2_100030
# 1024210          147.45039        DF1_100059        DF2_100048
# 1121454          147.45039        DF1_100086        DF2_100061
# 1092342          147.45039        DF1_100079        DF2_100083
# 883009           147.45039        DF1_100010        DF2_100061
# 1135186          147.45039        DF1_100046        DF2_100090
# 14688            147.45039        DF1_100026        DF2_100032
# 11099            147.45039        DF1_100081        DF2_100032
# 1086403          147.45039        DF1_100079        DF2_100085
# 809392           147.45039        DF1_100029        DF2_100023
# 1072830          147.45039        DF1_100029        DF2_100085
# 1121439          147.45039        DF1_100003        DF2_100006
# 853852           147.45039        DF1_100076        DF2_100067
#
#         latent_event_id_l latent_event_id_r match_key  is_true_match
# 1059368        UNI_A_1549       UNIQ_B_3464         0              0
# 1074888        UNI_A_1457       UNIQ_B_3328         0              0
# 1090465        UNI_A_1386       UNIQ_B_3245         0              0
# 1566            UNI_A_614           OVER_52         0              0
# 1100181        UNI_A_1353       UNIQ_B_3173         0              0
# 819158          UNI_A_945       UNIQ_B_2698         0              0
# 895057          UNI_A_598       UNIQ_B_2242         0              0
# 840377          UNI_A_715       UNIQ_B_2381         0              0
# 1024210        UNI_A_1651       UNIQ_B_3551         0              0
# 1121454        UNI_A_1139       UNIQ_B_2918         0              0
# 1092342        UNI_A_1348       UNIQ_B_3166         0              0
# 883009          UNI_A_348       UNIQ_B_1952         0              0
# 1135186        UNI_A_1166       UNIQ_B_2944         0              0
# 14688           UNI_A_165       UNIQ_B_1697         0              0
# 11099           UNI_A_404       UNIQ_B_2021         0              0
# 1086403        UNI_A_1316       UNIQ_B_3104         0              0
# 809392          UNI_A_970       UNIQ_B_2721         0              0
# 1072830        UNI_A_1388       UNIQ_B_3232         0              0
# 1121439        UNI_A_1137       UNIQ_B_2903         0              0
# 853852          UNI_A_534       UNIQ_B_2158         0              0

# %%
# False negatives
fn_examples = pd_predict[pd_predict["is_true_match"] == 1].sort_values(
    by="match_probability", ascending=True
)

fn_examples.head(20)
# Out:
#          match_weight  match_probability         source_dataset_l  \
# 622658     -15.026298           0.000030  __splink__input_table_0
# 1219342    -15.026298           0.000030  __splink__input_table_0
# 51131      -11.709305           0.000299  __splink__input_table_0
# 7224       -11.709305           0.000299  __splink__input_table_0
# 1068985    -11.709305           0.000299  __splink__input_table_0
# 881067     -11.709305           0.000299  __splink__input_table_0
# 1135033    -11.709305           0.000299  __splink__input_table_0
# 343327     -10.141538           0.000885  __splink__input_table_0
# 671945     -10.141538           0.000885  __splink__input_table_0
# 66005      -10.141538           0.000885  __splink__input_table_0
# 803215      -6.824545           0.008746  __splink__input_table_0
# 869753      -6.824545           0.008746  __splink__input_table_0
# 1092095     -6.824545           0.008746  __splink__input_table_0
# 1090436     -6.824545           0.008746  __splink__input_table_0
# 1067001     -6.824545           0.008746  __splink__input_table_0
# 1051458     -6.824545           0.008746  __splink__input_table_0
# 832691      -6.824545           0.008746  __splink__input_table_0
# 1022250     -6.824545           0.008746  __splink__input_table_0
# 877236      -6.824545           0.008746  __splink__input_table_0
# 871556      -6.824545           0.008746  __splink__input_table_0
#
#                 source_dataset_r  row_id_l  row_id_r  numerical_noisy_l  \
# 622658   __splink__input_table_1   df1_175   df2_246                NaN
# 1219342  __splink__input_table_1    df1_32    df2_45                NaN
# 51131    __splink__input_table_1   df1_122   df2_174                NaN
# 7224     __splink__input_table_1   df1_326   df2_425                NaN
# 1068985  __splink__input_table_1  df1_1416  df2_1758                NaN
# 881067   __splink__input_table_1   df1_234   df2_325                NaN
# 1135033  __splink__input_table_1   df1_995  df2_1210                NaN
# 343327   __splink__input_table_1  df1_1006  df2_1243            2884.69
# 671945   __splink__input_table_1    df1_66    df2_62             406.37
# 66005    __splink__input_table_1  df1_1655  df2_2064            1127.72
# 803215   __splink__input_table_1   df1_669   df2_815             268.25
# 869753   __splink__input_table_1   df1_644   df2_778            1518.93
# 1092095  __splink__input_table_1  df1_1122  df2_1359             218.93
# 1090436  __splink__input_table_1  df1_1349  df2_1667            2649.92
# 1067001  __splink__input_table_1  df1_1394  df2_1730            1956.67
# 1051458  __splink__input_table_1  df1_1490  df2_1856            1468.42
# 832691   __splink__input_table_1   df1_759   df2_925            1094.94
# 1022250  __splink__input_table_1  df1_1634  df2_2023            2480.44
# 877236   __splink__input_table_1   df1_314   df2_415             345.10
# 871556   __splink__input_table_1   df1_510   df2_617            1478.09
#
#          numerical_noisy_r  gamma_numerical_noisy  bf_numerical_noisy  \
# 622658                 NaN                     -1            1.000000
# 1219342                NaN                     -1            1.000000
# 51131                  NaN                     -1            1.000000
# 7224                   NaN                     -1            1.000000
# 1068985                NaN                     -1            1.000000
# 881067              464.82                     -1            1.000000
# 1135033             196.09                     -1            1.000000
# 343327             2885.89                      4           29.543322
# 671945              395.83                      4           29.543322
# 66005              1131.51                      4           29.543322
# 803215              266.91                      4           29.543322
# 869753             1521.51                      4           29.543322
# 1092095             218.68                      4           29.543322
# 1090436            2653.72                      4           29.543322
# 1067001            1958.12                      4           29.543322
# 1051458            1468.63                      4           29.543322
# 832691             1090.24                      4           29.543322
# 1022250            2478.54                      4           29.543322
# 877236              346.58                      4           29.543322
# 871556             1473.52                      4           29.543322
#
#         categorical_l categorical_r  gamma_categorical  bf_categorical  \
# 622658           None          None                 -1        1.000000
# 1219342          None          None                 -1        1.000000
# 51131           CAT_9         CAT_9                  1        9.965853
# 7224            CAT_7         CAT_7                  1        9.965853
# 1068985         CAT_3         CAT_3                  1        9.965853
# 881067          CAT_0         CAT_0                  1        9.965853
# 1135033         CAT_6         CAT_6                  1        9.965853
# 343327           None          None                 -1        1.000000
# 671945           None          None                 -1        1.000000
# 66005           CAT_1          None                 -1        1.000000
# 803215          CAT_5         CAT_5                  1        9.965853
# 869753          CAT_4         CAT_4                  1        9.965853
# 1092095         CAT_5         CAT_5                  1        9.965853
# 1090436         CAT_9         CAT_9                  1        9.965853
# 1067001         CAT_5         CAT_5                  1        9.965853
# 1051458         CAT_2         CAT_2                  1        9.965853
# 832691          CAT_9         CAT_9                  1        9.965853
# 1022250         CAT_6         CAT_6                  1        9.965853
# 877236          CAT_5         CAT_5                  1        9.965853
# 871556          CAT_7         CAT_7                  1        9.965853
#
#         datetime_noisy_l datetime_noisy_r  gamma_datetime_noisy  \
# 622658        2026-01-18       2026-01-17                     2
# 1219342       2026-01-03       2026-01-04                     2
# 51131         2026-01-12       2026-01-13                     2
# 7224          2026-02-01       2026-01-31                     2
# 1068985       2026-05-10       2026-05-09                     2
# 881067        2026-01-24       2026-01-23                     2
# 1135033       2026-04-02       2026-04-01                     2
# 343327        2026-04-02       2026-04-03                     2
# 671945        2026-01-06       2026-01-05                     2
# 66005         2026-05-30       2026-05-31                     2
# 803215        2026-03-03       2026-03-04                     2
# 869753        2026-03-02       2026-03-01                     2
# 1092095       2026-04-13       2026-04-12                     2
# 1090436       2026-05-03       2026-05-04                     2
# 1067001       2026-05-07       2026-05-08                     2
# 1051458       2026-05-17       2026-05-16                     2
# 832691        2026-03-12       2026-03-13                     2
# 1022250       2026-05-29       2026-05-28                     2
# 877236        2026-01-30       2026-01-31                     2
# 871556        2026-02-18       2026-02-17                     2
#
#          bf_datetime_noisy local_source_id_l local_source_id_r  \
# 622658            0.491572        DF1_100051        DF1_100051
# 1219342           0.491572        DF1_100075        DF1_100075
# 51131             0.491572        DF1_100075        DF1_100075
# 7224              0.491572        DF1_100087        DF1_100087
# 1068985           0.491572        DF1_100075        DF1_100075
# 881067            0.491572        DF1_100051        DF1_100051
# 1135033           0.491572        DF1_100075        DF1_100075
# 343327            0.491572        DF1_100039        DF1_100039
# 671945            0.491572        DF1_100051        DF1_100051
# 66005             0.491572        DF1_100075        DF1_100075
# 803215            0.491572        DF1_100087        DF1_100087
# 869753            0.491572        DF1_100087        DF1_100087
# 1092095           0.491572        DF1_100039        DF1_100039
# 1090436           0.491572        DF1_100075        DF1_100075
# 1067001           0.491572        DF1_100051        DF1_100051
# 1051458           0.491572        DF1_100039        DF1_100039
# 832691            0.491572        DF1_100073        DF1_100073
# 1022250           0.491572        DF1_100075        DF1_100075
# 877236            0.491572        DF1_100073        DF1_100073
# 871556            0.491572        DF1_100075        DF1_100075
#
#         latent_event_id_l latent_event_id_r match_key  is_true_match
# 622658            OVER_20           OVER_20         2              1
# 1219342            OVER_8            OVER_8         2              1
# 51131             OVER_15           OVER_15         0              1
# 7224              OVER_34           OVER_34         0              1
# 1068985          OVER_124          OVER_124         0              1
# 881067            OVER_26           OVER_26         0              1
# 1135033           OVER_91           OVER_91         0              1
# 343327            OVER_92           OVER_92         1              1
# 671945            OVER_11           OVER_11         1              1
# 66005            OVER_146          OVER_146         1              1
# 803215            OVER_63           OVER_63         0              1
# 869753            OVER_61           OVER_61         0              1
# 1092095           OVER_98           OVER_98         0              1
# 1090436          OVER_119          OVER_119         0              1
# 1067001          OVER_121          OVER_121         0              1
# 1051458          OVER_134          OVER_134         0              1
# 832691            OVER_70           OVER_70         0              1
# 1022250          OVER_143          OVER_143         0              1
# 877236            OVER_33           OVER_33         0              1
# 871556            OVER_48           OVER_48         0              1

# %% [markdown]
# We see that most of the results make sense - one minor unresolved issue is the discriminatory factor
# that numerical gives - intuitively it should make sense that the numerical comparison should provide
# larger match weights.
#
# However, considering a missingness of 5% on both ends - it translates to ~10% missingness in either
# columns - which also means 10% of our actual truths are immediately uncapturable.
#
# We also notice that the effect of the datetime shift is rather large.

# %% [markdown]
# ## Moving to aggregation

# %%
from notebook_helper import (
    aggregate_entity_pair_matched_pairs,
    compute_source_sizes,
    calculate_match_density,
    calculate_weighted_jaccard,
    calculate_weighted_overlap,
    calculate_score_prob_ratio,
    second_layer_splink_evaluation,
    save_score_distribution_plot,
    save_precision_recall_curve,
    get_savable_visualisations
)

U_BASE = linker._settings_obj._probability_two_random_records_match

aggregated_df = aggregate_entity_pair_matched_pairs(
    pd_predict,
    id_columns=['local_source_id_l', 'local_source_id_r']
)

print("Aggregated entity-pair DataFrame shape:", aggregated_df.shape)
print("\nColumns:", list(aggregated_df.columns))
print("\nFirst 5 rows:")
display(aggregated_df.head())
# Out:
# Aggregated entity-pair DataFrame shape: (2500, 8)
#
# Columns: ['local_source_id_l', 'local_source_id_r', 'sum_p', 'max_w', 'observed_edges', 'top_3_mean_w', 'score_noisy_or', 'score_softmax_p']
#
# First 5 rows:
# /home/local/KLASS/steven.zhu/Documents/entity_resolution_demo/helpers/entity_resolution_aggregation.py:247: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(apply_agg_functions)
#   local_source_id_l local_source_id_r     sum_p      max_w  observed_edges  \
# 0        DF1_100000        DF1_100039  0.000175 -12.793486             122
# 1        DF1_100000        DF1_100051  0.000209 -13.526550              93
# 2        DF1_100000        DF1_100073  0.000093 -13.526550              69
# 3        DF1_100000        DF1_100075  0.000230 -13.526550             164
# 4        DF1_100000        DF1_100087  0.000537 -11.453169              80
#
#    top_3_mean_w  score_noisy_or  score_softmax_p
# 0    -15.638774        0.000175         0.000001
# 1    -14.026466        0.000209         0.000002
# 2    -16.783057        0.000093         0.000001
# 3    -14.463676        0.000230         0.000001
# 4    -12.835423        0.000537         0.000007

# %%
source_sizes = compute_source_sizes(df1, df2, 'local_source_id')

def add_structural_metrics(row):
    # Get sizes for left and right entities
    size_l = source_sizes.get(row['local_source_id_l'], {'size_l': 0})['size_l']
    size_r = source_sizes.get(row['local_source_id_r'], {'size_r': 0})['size_r']
    
    # Match density
    row['match_density'] = calculate_match_density(
        row['sum_p'], size_l, size_r
    )
    # Weighted Jaccard
    row['weighted_jaccard'] = calculate_weighted_jaccard(
        row['sum_p'], size_l, size_r
    )
    # Weighted overlap
    row['weighted_overlap'] = calculate_weighted_overlap(
        row['sum_p'], size_l, size_r
    )
    # Score-probability expected ratio (requires u_base from your Splink model)
    # You can estimate u_base as the average match probability from the prior
    # or use the m/u probabilities from the linker; here we use a placeholder.
    # Replace u_base_estimate with your actual value from the linker training.
    u_base_estimate = U_BASE  # <-- UPDATE THIS with your linker's u probability
    row['score_prob_expected_ratio'] = calculate_score_prob_ratio(
        row['sum_p'], size_l, size_r, u_base_estimate
    )
    return row

aggregated_with_metrics = aggregated_df.apply(add_structural_metrics, axis=1)

print("\nAfter adding structural metrics:")
display(aggregated_with_metrics[['local_source_id_l', 'local_source_id_r',
                               'sum_p', 'match_density', 'weighted_jaccard',
                               'weighted_overlap', 'score_noisy_or', 'score_softmax_p' ,'score_prob_expected_ratio']].head())
# Out:
# After adding structural metrics:
#   local_source_id_l local_source_id_r     sum_p  match_density  \
# 0        DF1_100000        DF1_100039  0.000175   6.064265e-07
# 1        DF1_100000        DF1_100051  0.000209   8.024335e-07
# 2        DF1_100000        DF1_100073  0.000093   5.154734e-07
# 3        DF1_100000        DF1_100075  0.000230   5.672949e-07
# 4        DF1_100000        DF1_100087  0.000537   2.843106e-06
#
#    weighted_jaccard  weighted_overlap  score_noisy_or  score_softmax_p  \
# 0          0.000004          0.000019        0.000175         0.000001
# 1          0.000006          0.000023        0.000209         0.000002
# 2          0.000003          0.000010        0.000093         0.000001
# 3          0.000004          0.000026        0.000230         0.000001
# 4          0.000018          0.000060        0.000537         0.000007
#
#    score_prob_expected_ratio
# 0                  -4.604680
# 1                  -4.325567
# 2                  -4.762202
# 3                  -4.672734
# 4                  -3.063491

# %%
metrics_to_plot = [
    'match_density',
    'weighted_jaccard', 
    'weighted_overlap',
    'score_noisy_or',
    'score_softmax_p',
    'score_prob_expected_ratio'
]

# Create subplot layout
n_metrics = len(metrics_to_plot)
n_cols = min(3, n_metrics)
n_rows = (n_metrics + n_cols - 1) // n_cols  # Ceiling division

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
if n_metrics == 1:
    axes = [axes]
elif n_rows == 1:
    axes = axes.reshape(1, -1)

axes_flat = axes.flat if hasattr(axes, 'flat') else [axes]

# Plot each metric
for idx, col in enumerate(metrics_to_plot):
    if idx >= len(axes_flat):
        break
    ax = axes_flat[idx]
    
    # Get data and remove NaNs
    data = aggregated_with_metrics[col].dropna()
    if len(data) == 0:
        ax.text(0.5, 0.5, 'No data available', ha='center', va='center', transform=ax.transAxes)
        ax.set_title(f'{col} (No Data)')
        continue
    
    # Create histogram with KDE
    ax.hist(data, bins=30, alpha=0.7, color='skyblue', edgecolor='black', density=True)
    
    # Add KDE if scipy is available
    try:
        from scipy import stats
        kde = stats.gaussian_kde(data)
        x_range = np.linspace(data.min(), data.max(), 100)
        ax.plot(x_range, kde(x_range), 'darkblue', linewidth=2)
    except ImportError:
        pass  # Skip KDE if scipy not available
    
    ax.set_title(f'Distribution of {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Density')
    ax.grid(True, alpha=0.3)

# Hide unused subplots
for idx in range(len(metrics_to_plot), len(axes_flat)):
    axes_flat[idx].set_visible(False)

plt.suptitle('Distribution of Aggregation Strategies and Structural Metrics', fontsize=16)
plt.tight_layout()

# In notebook: show_and_save_fig(fig, "splink_local_demo", "combined_aggregation_metrics_distribution")
plt.show()  # For script execution

# %%
from helpers.visualization_helper import plot_aggregation_heatmaps, plot_threshold_evaluation

# Generate combined heatmap and precision-recall curves
plot_aggregation_heatmaps(
    aggregated_df=aggregated_with_metrics,  # or your aggregated dataframe
    score_columns=[
        'sum_p', 'max_w', 'top_3_mean_w', 
        'score_noisy_or', 'score_softmax_p',
        'match_density', 'weighted_jaccard', 
        'weighted_overlap', 'score_prob_expected_ratio'
    ],
    notebook_dir=NOTEBOOK_NAME
)
# Out:
# Figure saved to: /home/local/KLASS/steven.zhu/Documents/entity_resolution_demo/notebooks/images/splink_local_smallest/aggregation_score_heatmaps.png

# %%
plot_threshold_evaluation(
    aggregated_df=aggregated_with_metrics,
    df1=df1,
    df2=df2,
    score_columns=[
        'sum_p', 'max_w', 'top_3_mean_w', 
        'score_noisy_or', 'score_softmax_p',
        'match_density', 'weighted_jaccard', 
        'weighted_overlap', 'score_prob_expected_ratio'
    ],
    notebook_dir=NOTEBOOK_NAME,
    bins=30  # 30 bins as requeste
)
# Out:
# Computing entity-level ground truth for threshold evaluation...
# Found 5 true entity pairs out of 2500 total pairs (0.20%)
# Figure saved to: /home/local/KLASS/steven.zhu/Documents/entity_resolution_demo/notebooks/images/splink_local_smallest/threshold_evaluation_binned.png
